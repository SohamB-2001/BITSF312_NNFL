# %%
# !git clone https://github.com/brendenlake/omniglot
# !unzip omniglot/python/images_background.zip
# !unzip omniglot/python/images_evaluation.zip
# !mkdir weights data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: images_evaluation/Mongolian/character28/1386_05.png
#   inflating: images_evaluation/Mongolian/character28/1386_06.png
#   inflating: images_evaluation/Mongolian/character28/1386_07.png
#   inflating: images_evaluation/Mongolian/character28/1386_08.png
#   inflating: images_evaluation/Mongolian/character28/1386_09.png
#   inflating: images_evaluation/Mongolian/character28/1386_10.png
#   inflating: images_evaluation/Mongolian/character28/1386_11.png
#   inflating: images_evaluation/Mongolian/character28/1386_12.png
#   inflating: images_evaluation/Mongolian/character28/1386_13.png
#   inflating: images_evaluation/Mongolian/character28/1386_14.png
#   inflating: images_evaluation/Mongolian/character28/1386_15.png
#   inflating: images_evaluation/Mongolian/character28/1386_16.png
#   inflating: images_evaluation/Mongolian/character28/1386_17.png
#   inflating: images_evaluation/Mongolian/character28/1386_18.png
#   inflating: images_evaluation/Mongolian/character28/1386_19.png
#   inflating: images_evaluation/Mongolian/character28/1386_20.png
#    creating: images_evaluation/Mongolian/character29/
#   inflating: images_evaluation/Mongolian/character29/1387_01.png
#   inflating: images_evaluation/Mongolian/character29/1387_02.png
#   inflating: images_evaluation/Mongolian/character29/1387_03.png
#   inflating: images_evaluation/Mongolian/character29/1387_04.png
#   inflating: images_evaluation/Mongolian/character29/1387_05.png
#   inflating: images_evaluation/Mongolian/character29/1387_06.png
#   inflating: images_evaluation/Mongolian/character29/1387_07.png
#   inflating: images_evaluation/Mongolian/character29/1387_08.png
#   inflating: images_evaluation/Mongolian/character29/1387_09.png
#   inflating: images_evaluation/Mongolian/character29/1387_10.png
#   inflating: images_evaluation/Mongolian/character29/1387_11.png
#   inflating: images_evaluation/Mongolian/character29/1387_12.png
#   inflating: images_evaluation/Mongolian/character29/1387_13.png
#   inflating: images_evaluation/Mongolian/character29/1387_14.png
#   inflating: images_evaluation/Mongolian/character29/1387_15.png
#   inflating: images_evaluation/Mongolian/character29/1387_16.png
#   inflating: images_evaluation/Mongolian/character29/1387_17.png
#   inflating: images_evaluation/Mongolian/character29/1387_18.png
#   inflating: images_evaluation/Mongolian/character29/1387_19.png
#   inflating: images_evaluation/Mongolian/character29/1387_20.png
#    creating: images_evaluation/Mongolian/character30/
#   inflating: images_evaluation/Mongolian/character30/1388_01.png
#   inflating: images_evaluation/Mongolian/character30/1388_02.png
#   inflating: images_evaluation/Mongolian/character30/1388_03.png
#   inflating: images_evaluation/Mongolian/character30/1388_04.png
#   inflating: images_evaluation/Mongolian/character30/1388_05.png
#   inflating: images_evaluation/Mongolian/character30/1388_06.png
#   inflating: images_evaluation/Mongolian/character30/1388_07.png
#   inflating: images_evaluation/Mongolian/character30/1388_08.png
#   inflating: images_evaluation/Mongolian/character30/1388_09.png
#   inflating: images_evaluation/Mongolian/character30/1388_10.png
#   inflating: images_evaluation/Mongolian/character30/1388_11.png
#   inflating: images_evaluation/Mongolian/character30/1388_12.png
#   inflating: images_evaluation/Mongolian/character30/1388_13.png
#   inflating: images_evaluation/Mongolian/character30/1388_14.png
#   inflating: images_evaluation/Mongolian/character30/1388_15.png
#   inflating: images_evaluation/Mongolian/character30/1388_16.png
#   inflating: images_evaluation/Mongolian/character30/1388_17.png
#   inflating: images_evaluation/Mongolian/character30/1388_18.png
#   inflating: images_evaluation/Mongolian/character30/1388_19.png
#   inflating: images_evaluation/Mongolian/character30/1388_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character01/1389_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character02/1390_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character03/1391_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character04/1392_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character05/1393_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character06/1394_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character07/1395_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character08/1396_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character09/1397_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character10/1398_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character11/1399_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character12/1400_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character13/1401_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character14/1402_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character15/1403_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character16/1404_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character17/1405_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character18/1406_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character19/1407_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character20/1408_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character21/1409_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character22/1410_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_19.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character23/1411_20.png
#    creating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_01.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_02.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_03.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_04.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_05.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_06.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_07.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_08.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_09.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_10.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_11.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_12.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_13.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_14.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_15.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_16.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_17.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_18.png
#   inflating: images_evaluation/Old_Church_Slavonic_(Cyrillic)/character24/1412_19.png
# ...
#   inflating: images_evaluation/ULOG/character14/1611_13.png
#   inflating: images_evaluation/ULOG/character14/1611_14.png
#   inflating: images_evaluation/ULOG/character14/1611_15.png
#   inflating: images_evaluation/ULOG/character14/1611_16.png
#   inflating: images_evaluation/ULOG/character14/1611_17.png
#   inflating: images_evaluation/ULOG/character14/1611_18.png
#   inflating: images_evaluation/ULOG/character14/1611_19.png
#   inflating: images_evaluation/ULOG/character14/1611_20.png
#    creating: images_evaluation/ULOG/character15/
#   inflating: images_evaluation/ULOG/character15/1612_01.png
#   inflating: images_evaluation/ULOG/character15/1612_02.png
#   inflating: images_evaluation/ULOG/character15/1612_03.png
#   inflating: images_evaluation/ULOG/character15/1612_04.png
#   inflating: images_evaluation/ULOG/character15/1612_05.png
#   inflating: images_evaluation/ULOG/character15/1612_06.png
#   inflating: images_evaluation/ULOG/character15/1612_07.png
#   inflating: images_evaluation/ULOG/character15/1612_08.png
#   inflating: images_evaluation/ULOG/character15/1612_09.png
#   inflating: images_evaluation/ULOG/character15/1612_10.png
#   inflating: images_evaluation/ULOG/character15/1612_11.png
#   inflating: images_evaluation/ULOG/character15/1612_12.png
#   inflating: images_evaluation/ULOG/character15/1612_13.png
#   inflating: images_evaluation/ULOG/character15/1612_14.png
#   inflating: images_evaluation/ULOG/character15/1612_15.png
#   inflating: images_evaluation/ULOG/character15/1612_16.png
#   inflating: images_evaluation/ULOG/character15/1612_17.png
#   inflating: images_evaluation/ULOG/character15/1612_18.png
#   inflating: images_evaluation/ULOG/character15/1612_19.png
#   inflating: images_evaluation/ULOG/character15/1612_20.png
#    creating: images_evaluation/ULOG/character16/
#   inflating: images_evaluation/ULOG/character16/1613_01.png
#   inflating: images_evaluation/ULOG/character16/1613_02.png
#   inflating: images_evaluation/ULOG/character16/1613_03.png
#   inflating: images_evaluation/ULOG/character16/1613_04.png
#   inflating: images_evaluation/ULOG/character16/1613_05.png
#   inflating: images_evaluation/ULOG/character16/1613_06.png
#   inflating: images_evaluation/ULOG/character16/1613_07.png
#   inflating: images_evaluation/ULOG/character16/1613_08.png
#   inflating: images_evaluation/ULOG/character16/1613_09.png
#   inflating: images_evaluation/ULOG/character16/1613_10.png
#   inflating: images_evaluation/ULOG/character16/1613_11.png
#   inflating: images_evaluation/ULOG/character16/1613_12.png
#   inflating: images_evaluation/ULOG/character16/1613_13.png
#   inflating: images_evaluation/ULOG/character16/1613_14.png
#   inflating: images_evaluation/ULOG/character16/1613_15.png
#   inflating: images_evaluation/ULOG/character16/1613_16.png
#   inflating: images_evaluation/ULOG/character16/1613_17.png
#   inflating: images_evaluation/ULOG/character16/1613_18.png
#   inflating: images_evaluation/ULOG/character16/1613_19.png
#   inflating: images_evaluation/ULOG/character16/1613_20.png
#    creating: images_evaluation/ULOG/character17/
#   inflating: images_evaluation/ULOG/character17/1614_01.png
#   inflating: images_evaluation/ULOG/character17/1614_02.png
#   inflating: images_evaluation/ULOG/character17/1614_03.png
#   inflating: images_evaluation/ULOG/character17/1614_04.png
#   inflating: images_evaluation/ULOG/character17/1614_05.png
#   inflating: images_evaluation/ULOG/character17/1614_06.png
#   inflating: images_evaluation/ULOG/character17/1614_07.png
#   inflating: images_evaluation/ULOG/character17/1614_08.png
#   inflating: images_evaluation/ULOG/character17/1614_09.png
#   inflating: images_evaluation/ULOG/character17/1614_10.png
#   inflating: images_evaluation/ULOG/character17/1614_11.png
#   inflating: images_evaluation/ULOG/character17/1614_12.png
#   inflating: images_evaluation/ULOG/character17/1614_13.png
#   inflating: images_evaluation/ULOG/character17/1614_14.png
#   inflating: images_evaluation/ULOG/character17/1614_15.png
#   inflating: images_evaluation/ULOG/character17/1614_16.png
#   inflating: images_evaluation/ULOG/character17/1614_17.png
#   inflating: images_evaluation/ULOG/character17/1614_18.png
#   inflating: images_evaluation/ULOG/character17/1614_19.png
#   inflating: images_evaluation/ULOG/character17/1614_20.png
#    creating: images_evaluation/ULOG/character18/
#   inflating: images_evaluation/ULOG/character18/1615_01.png
#   inflating: images_evaluation/ULOG/character18/1615_02.png
#   inflating: images_evaluation/ULOG/character18/1615_03.png
#   inflating: images_evaluation/ULOG/character18/1615_04.png
#   inflating: images_evaluation/ULOG/character18/1615_05.png
#   inflating: images_evaluation/ULOG/character18/1615_06.png
#   inflating: images_evaluation/ULOG/character18/1615_07.png
#   inflating: images_evaluation/ULOG/character18/1615_08.png
#   inflating: images_evaluation/ULOG/character18/1615_09.png
#   inflating: images_evaluation/ULOG/character18/1615_10.png
#   inflating: images_evaluation/ULOG/character18/1615_11.png
#   inflating: images_evaluation/ULOG/character18/1615_12.png
#   inflating: images_evaluation/ULOG/character18/1615_13.png
#   inflating: images_evaluation/ULOG/character18/1615_14.png
#   inflating: images_evaluation/ULOG/character18/1615_15.png
#   inflating: images_evaluation/ULOG/character18/1615_16.png
#   inflating: images_evaluation/ULOG/character18/1615_17.png
#   inflating: images_evaluation/ULOG/character18/1615_18.png
#   inflating: images_evaluation/ULOG/character18/1615_19.png
#   inflating: images_evaluation/ULOG/character18/1615_20.png
#    creating: images_evaluation/ULOG/character19/
#   inflating: images_evaluation/ULOG/character19/1616_01.png
#   inflating: images_evaluation/ULOG/character19/1616_02.png
#   inflating: images_evaluation/ULOG/character19/1616_03.png
#   inflating: images_evaluation/ULOG/character19/1616_04.png
#   inflating: images_evaluation/ULOG/character19/1616_05.png
#   inflating: images_evaluation/ULOG/character19/1616_06.png
#   inflating: images_evaluation/ULOG/character19/1616_07.png
#   inflating: images_evaluation/ULOG/character19/1616_08.png
#   inflating: images_evaluation/ULOG/character19/1616_09.png
#   inflating: images_evaluation/ULOG/character19/1616_10.png
#   inflating: images_evaluation/ULOG/character19/1616_11.png
#   inflating: images_evaluation/ULOG/character19/1616_12.png
#   inflating: images_evaluation/ULOG/character19/1616_13.png
#   inflating: images_evaluation/ULOG/character19/1616_14.png
#   inflating: images_evaluation/ULOG/character19/1616_15.png
#   inflating: images_evaluation/ULOG/character19/1616_16.png
#   inflating: images_evaluation/ULOG/character19/1616_17.png
#   inflating: images_evaluation/ULOG/character19/1616_18.png
#   inflating: images_evaluation/ULOG/character19/1616_19.png
#   inflating: images_evaluation/ULOG/character19/1616_20.png
#    creating: images_evaluation/ULOG/character20/
#   inflating: images_evaluation/ULOG/character20/1617_01.png
#   inflating: images_evaluation/ULOG/character20/1617_02.png
#   inflating: images_evaluation/ULOG/character20/1617_03.png
#   inflating: images_evaluation/ULOG/character20/1617_04.png
#   inflating: images_evaluation/ULOG/character20/1617_05.png
#   inflating: images_evaluation/ULOG/character20/1617_06.png
#   inflating: images_evaluation/ULOG/character20/1617_07.png
#   inflating: images_evaluation/ULOG/character20/1617_08.png
#   inflating: images_evaluation/ULOG/character20/1617_09.png
#   inflating: images_evaluation/ULOG/character20/1617_10.png
#   inflating: images_evaluation/ULOG/character20/1617_11.png
#   inflating: images_evaluation/ULOG/character20/1617_12.png
#   inflating: images_evaluation/ULOG/character20/1617_13.png
#   inflating: images_evaluation/ULOG/character20/1617_14.png
#   inflating: images_evaluation/ULOG/character20/1617_15.png
#   inflating: images_evaluation/ULOG/character20/1617_16.png
#   inflating: images_evaluation/ULOG/character20/1617_17.png
#   inflating: images_evaluation/ULOG/character20/1617_18.png
#   inflating: images_evaluation/ULOG/character20/1617_19.png
#   inflating: images_evaluation/ULOG/character20/1617_20.png
#    creating: images_evaluation/ULOG/character21/
#   inflating: images_evaluation/ULOG/character21/1618_01.png
#   inflating: images_evaluation/ULOG/character21/1618_02.png
#   inflating: images_evaluation/ULOG/character21/1618_03.png
#   inflating: images_evaluation/ULOG/character21/1618_04.png
#   inflating: images_evaluation/ULOG/character21/1618_05.png
#   inflating: images_evaluation/ULOG/character21/1618_06.png
#   inflating: images_evaluation/ULOG/character21/1618_07.png
#   inflating: images_evaluation/ULOG/character21/1618_08.png
#   inflating: images_evaluation/ULOG/character21/1618_09.png
#   inflating: images_evaluation/ULOG/character21/1618_10.png
#   inflating: images_evaluation/ULOG/character21/1618_11.png
#   inflating: images_evaluation/ULOG/character21/1618_12.png
#   inflating: images_evaluation/ULOG/character21/1618_13.png
#   inflating: images_evaluation/ULOG/character21/1618_14.png
#   inflating: images_evaluation/ULOG/character21/1618_15.png
#   inflating: images_evaluation/ULOG/character21/1618_16.png
#   inflating: images_evaluation/ULOG/character21/1618_17.png
#   inflating: images_evaluation/ULOG/character21/1618_18.png
#   inflating: images_evaluation/ULOG/character21/1618_19.png
#   inflating: images_evaluation/ULOG/character21/1618_20.png
#    creating: images_evaluation/ULOG/character22/
#   inflating: images_evaluation/ULOG/character22/1619_01.png
#   inflating: images_evaluation/ULOG/character22/1619_02.png
#   inflating: images_evaluation/ULOG/character22/1619_03.png
#   inflating: images_evaluation/ULOG/character22/1619_04.png
#   inflating: images_evaluation/ULOG/character22/1619_05.png
#   inflating: images_evaluation/ULOG/character22/1619_06.png
#   inflating: images_evaluation/ULOG/character22/1619_07.png
#   inflating: images_evaluation/ULOG/character22/1619_08.png
#   inflating: images_evaluation/ULOG/character22/1619_09.png
#   inflating: images_evaluation/ULOG/character22/1619_10.png
#   inflating: images_evaluation/ULOG/character22/1619_11.png
#   inflating: images_evaluation/ULOG/character22/1619_12.png
#   inflating: images_evaluation/ULOG/character22/1619_13.png
#   inflating: images_evaluation/ULOG/character22/1619_14.png
#   inflating: images_evaluation/ULOG/character22/1619_15.png
#   inflating: images_evaluation/ULOG/character22/1619_16.png
#   inflating: images_evaluation/ULOG/character22/1619_17.png
#   inflating: images_evaluation/ULOG/character22/1619_18.png
#   inflating: images_evaluation/ULOG/character22/1619_19.png
#   inflating: images_evaluation/ULOG/character22/1619_20.png
#    creating: images_evaluation/ULOG/character23/
#   inflating: images_evaluation/ULOG/character23/1620_01.png
#   inflating: images_evaluation/ULOG/character23/1620_02.png
#   inflating: images_evaluation/ULOG/character23/1620_03.png
#   inflating: images_evaluation/ULOG/character23/1620_04.png
#   inflating: images_evaluation/ULOG/character23/1620_05.png
#   inflating: images_evaluation/ULOG/character23/1620_06.png
#   inflating: images_evaluation/ULOG/character23/1620_07.png
#   inflating: images_evaluation/ULOG/character23/1620_08.png
#   inflating: images_evaluation/ULOG/character23/1620_09.png
#   inflating: images_evaluation/ULOG/character23/1620_10.png
#   inflating: images_evaluation/ULOG/character23/1620_11.png
#   inflating: images_evaluation/ULOG/character23/1620_12.png
#   inflating: images_evaluation/ULOG/character23/1620_13.png
#   inflating: images_evaluation/ULOG/character23/1620_14.png
#   inflating: images_evaluation/ULOG/character23/1620_15.png
#   inflating: images_evaluation/ULOG/character23/1620_16.png
#   inflating: images_evaluation/ULOG/character23/1620_17.png
#   inflating: images_evaluation/ULOG/character23/1620_18.png
#   inflating: images_evaluation/ULOG/character23/1620_19.png
#   inflating: images_evaluation/ULOG/character23/1620_20.png
#    creating: images_evaluation/ULOG/character24/
#   inflating: images_evaluation/ULOG/character24/1621_01.png
#   inflating: images_evaluation/ULOG/character24/1621_02.png
#   inflating: images_evaluation/ULOG/character24/1621_03.png
#   inflating: images_evaluation/ULOG/character24/1621_04.png
#   inflating: images_evaluation/ULOG/character24/1621_05.png
#   inflating: images_evaluation/ULOG/character24/1621_06.png
#   inflating: images_evaluation/ULOG/character24/1621_07.png
#   inflating: images_evaluation/ULOG/character24/1621_08.png
#   inflating: images_evaluation/ULOG/character24/1621_09.png
#   inflating: images_evaluation/ULOG/character24/1621_10.png
#   inflating: images_evaluation/ULOG/character24/1621_11.png
#   inflating: images_evaluation/ULOG/character24/1621_12.png
#   inflating: images_evaluation/ULOG/character24/1621_13.png
#   inflating: images_evaluation/ULOG/character24/1621_14.png
#   inflating: images_evaluation/ULOG/character24/1621_15.png
#   inflating: images_evaluation/ULOG/character24/1621_16.png
#   inflating: images_evaluation/ULOG/character24/1621_17.png
#   inflating: images_evaluation/ULOG/character24/1621_18.png
#   inflating: images_evaluation/ULOG/character24/1621_19.png
#   inflating: images_evaluation/ULOG/character24/1621_20.png
#    creating: images_evaluation/ULOG/character25/
#   inflating: images_evaluation/ULOG/character25/1622_01.png
#   inflating: images_evaluation/ULOG/character25/1622_02.png
#   inflating: images_evaluation/ULOG/character25/1622_03.png
#   inflating: images_evaluation/ULOG/character25/1622_04.png
#   inflating: images_evaluation/ULOG/character25/1622_05.png
#   inflating: images_evaluation/ULOG/character25/1622_06.png
#   inflating: images_evaluation/ULOG/character25/1622_07.png
#   inflating: images_evaluation/ULOG/character25/1622_08.png
#   inflating: images_evaluation/ULOG/character25/1622_09.png
#   inflating: images_evaluation/ULOG/character25/1622_10.png
#   inflating: images_evaluation/ULOG/character25/1622_11.png
#   inflating: images_evaluation/ULOG/character25/1622_12.png
#   inflating: images_evaluation/ULOG/character25/1622_13.png
#   inflating: images_evaluation/ULOG/character25/1622_14.png
#   inflating: images_evaluation/ULOG/character25/1622_15.png
#   inflating: images_evaluation/ULOG/character25/1622_16.png
#   inflating: images_evaluation/ULOG/character25/1622_17.png
#   inflating: images_evaluation/ULOG/character25/1622_18.png
#   inflating: images_evaluation/ULOG/character25/1622_19.png
#   inflating: images_evaluation/ULOG/character25/1622_20.png
#    creating: images_evaluation/ULOG/character26/
#   inflating: images_evaluation/ULOG/character26/1623_01.png
#   inflating: images_evaluation/ULOG/character26/1623_02.png
#   inflating: images_evaluation/ULOG/character26/1623_03.png
#   inflating: images_evaluation/ULOG/character26/1623_04.png
#   inflating: images_evaluation/ULOG/character26/1623_05.png
#   inflating: images_evaluation/ULOG/character26/1623_06.png
#   inflating: images_evaluation/ULOG/character26/1623_07.png
#   inflating: images_evaluation/ULOG/character26/1623_08.png
#   inflating: images_evaluation/ULOG/character26/1623_09.png
#   inflating: images_evaluation/ULOG/character26/1623_10.png
#   inflating: images_evaluation/ULOG/character26/1623_11.png
#   inflating: images_evaluation/ULOG/character26/1623_12.png
#   inflating: images_evaluation/ULOG/character26/1623_13.png
#   inflating: images_evaluation/ULOG/character26/1623_14.png
#   inflating: images_evaluation/ULOG/character26/1623_15.png
#   inflating: images_evaluation/ULOG/character26/1623_16.png
#   inflating: images_evaluation/ULOG/character26/1623_17.png
#   inflating: images_evaluation/ULOG/character26/1623_18.png
#   inflating: images_evaluation/ULOG/character26/1623_19.png
#   inflating: images_evaluation/ULOG/character26/1623_20.png

# %%
import sys
import numpy as np
import pandas as pd
from imageio import imread
import pickle
import os
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
import time
import keras
import tensorflow as tf
from keras.models import Sequential
from tensorflow.keras.optimizers import schedules, Adam
from tensorflow.keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate, BatchNormalization
from tensorflow.keras.models import Model

from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.initializers import glorot_uniform

from tensorflow.keras.layers import Layer
from keras.regularizers import l2
from keras import backend as K

from sklearn.utils import shuffle

import numpy.random as rng

# %%
train_folder = "images_background"
val_folder = 'images_evaluation'
save_path = 'data'

# %%
def loadimgs(path,n = 0):
    '''
    path => Path of train directory or test directory
    '''
    X=[]
    y = []
    cat_dict = {}
    lang_dict = {}
    curr_y = n
    # we load every alphabet seperately so we can isolate them later
    for alphabet in os.listdir(path):
        # print("loading alphabet: " + alphabet)
        lang_dict[alphabet] = [curr_y,None]
        alphabet_path = os.path.join(path,alphabet)
        # every letter/category has it's own column in the array, so  load seperately
        for letter in os.listdir(alphabet_path):
            cat_dict[curr_y] = (alphabet, letter)
            category_images=[]
            letter_path = os.path.join(alphabet_path, letter)
            # read all the images in the current category
            for filename in os.listdir(letter_path):
                image_path = os.path.join(letter_path, filename)
                image = imread(image_path)
                category_images.append(image)
                y.append(curr_y)
            try:
                X.append(np.stack(category_images))
            # edge case  - last one
            except ValueError as e:
                print(e)
                print("error - category_images:", category_images)
            curr_y += 1
            lang_dict[alphabet][1] = curr_y - 1
    y = np.vstack(y)
    X = np.stack(X)
    return X,y,lang_dict

# %%
X,y,c=loadimgs(train_folder)

# %%
with open(os.path.join(save_path,"train.pickle"), "wb") as f:
    pickle.dump((X,c),f)

# %%
Xval,yval,cval=loadimgs(val_folder)

# %%
with open(os.path.join(save_path,"val.pickle"), "wb") as f:
    pickle.dump((Xval,cval),f)

# %%
def initialize_weights(shape, dtype=None):
    return np.random.normal(loc = 0.0, scale = 1e-2, size = shape)
def initialize_bias(shape, dtype=None):
    return np.random.normal(loc = 0.5, scale = 1e-2, size = shape)

# %%
def get_siamese_model(input_shape):
  
    # Define the tensors for the two input images
    left_input = Input(input_shape)
    right_input = Input(input_shape)
    
    # Convolutional Neural Network
    model = Sequential()
    model.add(Conv2D(64, (10,10), activation='selu', input_shape=input_shape,
                   kernel_initializer=initialize_weights, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(128, (7,7), activation='selu',
                     kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(128, (4,4), activation='selu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(256, (4,4), activation='selu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(Flatten())
    model.add(Dense(4096, activation='sigmoid',
                   kernel_regularizer=l2(1e-3),
                   kernel_initializer=initialize_weights,bias_initializer=initialize_bias))
    
    # Generate the encodings (feature vectors) for the two images
    encoded_l = model(left_input)
    encoded_r = model(right_input)
    
    # Add a customized layer to compute the absolute difference between the encodings
    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    L1_distance = (L1_layer([encoded_l, encoded_r]))
    
    # Add a dense layer with a sigmoid unit to generate the similarity score
    prediction = Dense(1,activation='sigmoid',bias_initializer=initialize_bias)(L1_distance)
    
    # Connect the inputs with the outputs
    siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)
    
    # return the model
    return siamese_net

# %%
model = get_siamese_model((105, 105, 1))
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 105, 105, 1  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 105, 105, 1  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 4096)         38947648    ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lambda (Lambda)                (None, 4096)         0           ['sequential[0][0]',
#                                                                   'sequential[1][0]']
#
#  dense_1 (Dense)                (None, 1)            4097        ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 38,951,745
# Trainable params: 38,951,745
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
lr_schedule = schedules.ExponentialDecay(
    initial_learning_rate=0.00009,
    decay_steps=10000,
    decay_rate=0.99)
optimizer = Adam(learning_rate = lr_schedule)
model.compile(loss="binary_crossentropy",optimizer=optimizer)

# %%
with open(os.path.join(save_path, "train.pickle"), "rb") as f:
    (Xtrain, train_classes) = pickle.load(f)
    
print("Training alphabets: \n")
print(list(train_classes.keys()))
# Out:
# Training alphabets:
#
# ['Tifinagh', 'Korean', 'Tagalog', 'Burmese_(Myanmar)', 'Greek', 'Japanese_(hiragana)', 'Syriac_(Estrangelo)', 'Early_Aramaic', 'Balinese', 'Latin', 'Grantha', 'Blackfoot_(Canadian_Aboriginal_Syllabics)', 'Cyrillic', 'Armenian', 'Malay_(Jawi_-_Arabic)', 'Alphabet_of_the_Magi', 'Braille', 'Asomtavruli_(Georgian)', 'Mkhedruli_(Georgian)', 'Inuktitut_(Canadian_Aboriginal_Syllabics)', 'Anglo-Saxon_Futhorc', 'Hebrew', 'Bengali', 'Gujarati', 'Japanese_(katakana)', 'Arcadian', 'N_Ko', 'Sanskrit', 'Ojibwe_(Canadian_Aboriginal_Syllabics)', 'Futurama']

# %%
with open(os.path.join(save_path, "val.pickle"), "rb") as f:
    (Xval, val_classes) = pickle.load(f)

print("Validation alphabets:", end="\n\n")
print(list(val_classes.keys()))
# Out:
# Validation alphabets:
#
# ['Avesta', 'Ge_ez', 'Kannada', 'Angelic', 'Atemayar_Qelisayer', 'Keble', 'Tengwar', 'Gurmukhi', 'Glagolitic', 'Syriac_(Serto)', 'Sylheti', 'Mongolian', 'Oriya', 'Malayalam', 'ULOG', 'Manipuri', 'Aurek-Besh', 'Tibetan', 'Atlantean', 'Old_Church_Slavonic_(Cyrillic)']

# %%
def get_batch(batch_size,s="train"):
    """Create batch of n pairs, half same class, half different class"""
    if s == 'train':
        X = Xtrain
        categories = train_classes
    else:
        X = Xval
        categories = val_classes
    n_classes, n_examples, w, h = X.shape

    # randomly sample several classes to use in the batch
    categories = rng.choice(n_classes,size=(batch_size,),replace=False)
    
    # initialize 2 empty arrays for the input image batch
    pairs=[np.zeros((batch_size, h, w,1)) for i in range(2)]
    
    # initialize vector for the targets
    targets=np.zeros((batch_size,))
    
    # make one half of it '1's, so 2nd half of batch has same class
    targets[batch_size//2:] = 1
    for i in range(batch_size):
        category = categories[i]
        idx_1 = rng.randint(0, n_examples)
        pairs[0][i,:,:,:] = X[category, idx_1].reshape(w, h, 1)
        idx_2 = rng.randint(0, n_examples)
        
        # pick images of same class for 1st half, different for 2nd
        if i >= batch_size // 2:
            category_2 = category  
        else: 
            # add a random number to the category modulo n classes to ensure 2nd image has a different category
            category_2 = (category + rng.randint(1,n_classes)) % n_classes
        
        pairs[1][i,:,:,:] = X[category_2,idx_2].reshape(w, h,1)
    
    return pairs, targets

# %%
def generate(batch_size, s="train"):
    """a generator for batches, so model.fit_generator can be used. """
    while True:
        pairs, targets = get_batch(batch_size,s)
        yield (pairs, targets)

# %%
def make_oneshot_task(N, s="val", language=None):
    """Create pairs of test image, support set for testing N way one-shot learning. """
    if s == 'train':
        X = Xtrain
        categories = train_classes
    else:
        X = Xval
        categories = val_classes
    n_classes, n_examples, w, h = X.shape
    
    indices = rng.randint(0, n_examples,size=(N,))
    if language is not None: # if language is specified, select characters for that language
        low, high = categories[language]
        if N > high - low:
            raise ValueError("This language ({}) has less than {} letters".format(language, N))
        categories = rng.choice(range(low,high),size=(N,),replace=False)

    else: # if no language specified just pick a bunch of random letters
        categories = rng.choice(range(n_classes),size=(N,),replace=False)            
    true_category = categories[0]
    ex1, ex2 = rng.choice(n_examples,replace=False,size=(2,))
    test_image = np.asarray([X[true_category,ex1,:,:]]*N).reshape(N, w, h,1)
    support_set = X[categories,indices,:,:]
    support_set[0,:,:] = X[true_category,ex2]
    support_set = support_set.reshape(N, w, h,1)
    targets = np.zeros((N,))
    targets[0] = 1
    targets, test_image, support_set = shuffle(targets, test_image, support_set)
    pairs = [test_image,support_set]

    return pairs, targets

# %%
def test_oneshot(model, N, k, s = "val", verbose = 0):
    n_correct = 0
    if verbose:
        print("Evaluating model on {} random {} way one-shot learning tasks ... \n".format(k,N))
    for i in range(k):
        inputs, targets = make_oneshot_task(N,s)
        loss = model.train_on_batch(inputs, targets)
        probs = model.predict(inputs)
        if np.argmax(probs) == np.argmax(targets):
            n_correct+=1
    percent_correct = (100.0 * n_correct / k)
    if verbose:
        print("Val Loss: {}".format(loss))
        print("Got an average of {}% {} way one-shot learning accuracy \n".format(percent_correct,N))
    return percent_correct

# %%
# Hyper parameters
evaluate_every = 200
batch_size = 256
n_iter = 1000
N_way = 20 
n_val = 250 
best = -1

# %%
model_path = './weights/'

# %%
print("Starting training process!")
print("-------------------------------------")
t_start = time.time()
for i in range(1, n_iter+1):
    (inputs,targets) = get_batch(batch_size)
    loss = model.train_on_batch(inputs, targets)
    if i % evaluate_every == 0:
        print("\n ------------- \n")
        print("Time for {0} iterations: {1} mins".format(i, (time.time()-t_start)/60.0))
        print("Train Loss: {0}".format(loss)) 
        val_acc = test_oneshot(model, N_way, n_val, verbose=True)
        model.save_weights(os.path.join(model_path, 'weights.{}.h5'.format(i)))
        if val_acc >= best:
            print("Current best: {0}, previous best: {1}".format(val_acc, best))
            best = val_acc
# Out:
# Starting training process!
# -------------------------------------
#
#  -------------
#
# Time for 1 iterations: 0.24456568956375122 mins
# Train Loss: 4.519860744476318
# Evaluating model on 250 random 20 way one-shot learning tasks ...
#
# Val Loss: 1.4259973764419556
# Got an average of 63.6% 20 way one-shot learning accuracy
#
# Current best: 63.6, previous best: -1

# %%
model.load_weights(os.path.join(model_path, f'weights.{n_iter}.h5'))

# %%
def nearest_neighbour_correct(pairs,targets):
    """returns 1 if nearest neighbour gets the correct answer for a one-shot task
        given by (pairs, targets)"""
    L2_distances = np.zeros_like(targets)
    for i in range(len(targets)):
        L2_distances[i] = np.sum(np.sqrt(pairs[0][i]**2 - pairs[1][i]**2))
    if np.argmin(L2_distances) == np.argmax(targets):
        return 1
    return 0

# %%
def test_nn_accuracy(N_ways,n_trials):
    """Returns accuracy of NN approach """
    print("Evaluating nearest neighbour on {} unique {} way one-shot learning tasks ...".format(n_trials,N_ways))

    n_right = 0
    
    for i in range(n_trials):
        pairs,targets = make_oneshot_task(N_ways,"val")
        correct = nearest_neighbour_correct(pairs,targets)
        n_right += correct
    return 100.0 * n_right / n_trials

# %%
ways = np.arange(1,20,2)
resume =  False
trials = 50

# %%
val_accs, train_accs,nn_accs = [], [], []
for N in ways:    
    val_accs.append(test_oneshot(model, N, trials, "val", verbose=True))
    train_accs.append(test_oneshot(model, N, trials, "train", verbose=True))
    nn_acc = test_nn_accuracy(N, trials)
    nn_accs.append(nn_acc)
    print ("NN Accuracy = ", nn_acc)
    print("---------------------------------------------------------------------------------------------------------------")
# Out:
# Evaluating model on 50 random 1 way one-shot learning tasks ...
#
# Val Loss: 1.54979407787323
# Got an average of 100.0% 1 way one-shot learning accuracy
#
# Evaluating model on 50 random 1 way one-shot learning tasks ...
#
# Val Loss: 1.4059441089630127
# Got an average of 100.0% 1 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 1 way one-shot learning tasks ...
# NN Accuracy =  100.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 3 way one-shot learning tasks ...
#
# Val Loss: 1.6331486701965332
# Got an average of 46.0% 3 way one-shot learning accuracy
#
# Evaluating model on 50 random 3 way one-shot learning tasks ...
#
# Val Loss: 1.5340157747268677
# Got an average of 54.0% 3 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 3 way one-shot learning tasks ...
# NN Accuracy =  66.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 5 way one-shot learning tasks ...
#
# Val Loss: 1.5187456607818604
# Got an average of 30.0% 5 way one-shot learning accuracy
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
#
# Val Loss: 1.4463212490081787
# Got an average of 44.0% 5 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 5 way one-shot learning tasks ...
# NN Accuracy =  50.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 7 way one-shot learning tasks ...
#
# Val Loss: 1.412815809249878
# Got an average of 26.0% 7 way one-shot learning accuracy
#
# Evaluating model on 50 random 7 way one-shot learning tasks ...
#
# Val Loss: 1.3574386835098267
# Got an average of 28.0% 7 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 7 way one-shot learning tasks ...
# NN Accuracy =  42.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 9 way one-shot learning tasks ...
#
# Val Loss: 1.326006531715393
# Got an average of 14.0% 9 way one-shot learning accuracy
#
# Evaluating model on 50 random 9 way one-shot learning tasks ...
#
# Val Loss: 1.2023462057113647
# Got an average of 30.0% 9 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 9 way one-shot learning tasks ...
# NN Accuracy =  30.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 11 way one-shot learning tasks ...
#
# Val Loss: 1.3052111864089966
# Got an average of 14.0% 11 way one-shot learning accuracy
#
# Evaluating model on 50 random 11 way one-shot learning tasks ...
#
# Val Loss: 1.2757079601287842
# Got an average of 4.0% 11 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 11 way one-shot learning tasks ...
# NN Accuracy =  30.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 13 way one-shot learning tasks ...
#
# Val Loss: 1.24754798412323
# Got an average of 10.0% 13 way one-shot learning accuracy
#
# Evaluating model on 50 random 13 way one-shot learning tasks ...
#
# Val Loss: 1.2178940773010254
# Got an average of 14.0% 13 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 13 way one-shot learning tasks ...
# NN Accuracy =  32.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 15 way one-shot learning tasks ...
#
# Val Loss: 1.196063756942749
# Got an average of 14.0% 15 way one-shot learning accuracy
#
# Evaluating model on 50 random 15 way one-shot learning tasks ...
#
# Val Loss: 1.1723600625991821
# Got an average of 12.0% 15 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 15 way one-shot learning tasks ...
# NN Accuracy =  26.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 17 way one-shot learning tasks ...
#
# Val Loss: 1.1540906429290771
# Got an average of 6.0% 17 way one-shot learning accuracy
#
# Evaluating model on 50 random 17 way one-shot learning tasks ...
#
# Val Loss: 1.1345784664154053
# Got an average of 14.0% 17 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 17 way one-shot learning tasks ...
# NN Accuracy =  26.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 19 way one-shot learning tasks ...
#
# Val Loss: 1.1191052198410034
# Got an average of 14.0% 19 way one-shot learning accuracy
#
# Evaluating model on 50 random 19 way one-shot learning tasks ...
#
# Val Loss: 1.1023272275924683
# Got an average of 12.0% 19 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 19 way one-shot learning tasks ...
# NN Accuracy =  34.0
# ---------------------------------------------------------------------------------------------------------------

# %%
def plot_oneshot_task(pairs):
    fig,(ax1,ax2) = plt.subplots(nrows=1, ncols=2)
    ax1.matshow(pairs[0][0].reshape(105,105), cmap='gray')
    img = concat_images(pairs[1])
    ax1.get_yaxis().set_visible(False)
    ax1.get_xaxis().set_visible(False)
    ax2.matshow(img,cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %%
fig,ax = plt.subplots(1)
# ax.plot(ways, val_accs, "m", label="Siamese(val set)")
# ax.plot(ways, train_accs, "y", label="Siamese(train set)")
plt.plot(ways, nn_accs, label="Nearest neighbour")

# ax.plot(ways, 100.0/ways, "g", label="Random guessing")
plt.xlabel("Number of possible classes in one-shot tasks")
plt.ylabel("% Accuracy")
plt.title("Nearest Neighbour Classifier")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# inputs,targets = make_oneshot_task(20, "val", 'Oriya')
plt.show()

# plot_oneshot_task(inputs)
